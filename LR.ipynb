# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv("lung.csv.csv")

# %%
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
 sns.lmplot(x='age',y=''

# %%
sns.lmplot(x='AGE',y='ALCOHOL CONSUMING',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['AGE']],df['ALCOHOL CONSUMING'])
# Out:
# LinearRegression()

# %%
reg.predict([[90]])
# Out:
# C:\Users\Elaf Fatima\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.65432252])

# %%
y=mx+c

# %%
 m =  reg.coef_
m
# Out:
# array([0.00357481])

# %%
c =reg.intercept_
c
# Out:
# 1.3325900240263588

# %%
x=df['AGE']
y=df['ALCOHOL CONSUMING']

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("AGE")
plt.ylabel("ALCOHOL CONSUMING")
# Out:
# Text(0, 0.5, 'ALCOHOL CONSUMING')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.4, random_state=35)

# %%
x_train
# Out:
# 251    64
# 174    72
# 213    64
# 43     52
# 113    60
#        ..
# 232    62
# 249    68
# 33     67
# 271    63
# 201    60
# Name: AGE, Length: 185, dtype: int64

# %%
import numpy as np
x_train = np.array(x_train).reshape(-1,1)
x_train
# Out:
# array([[64],
#        [72],
#        [64],
#        [52],
#        [60],
#        [70],
#        [51],
#        [62],
#        [63],
#        [67],
#        [59],
#        [63],
#        [63],
#        [69],
#        [44],
#        [61],
#        [56],
#        [55],
#        [51],
#        [64],
#        [64],
#        [64],
#        [62],
#        [70],
#        [57],
#        [58],
#        [70],
#        [59],
#        [46],
#        [59],
#        [67],
#        [51],
#        [77],
#        [72],
#        [56],
#        [61],
#        [54],
#        [57],
#        [70],
#        [39],
#        [78],
#        [58],
#        [87],
#        [47],
#        [52],
#        [68],
#        [71],
#        [48],
#        [63],
#        [70],
#        [68],
#        [77],
#        [63],
#        [62],
#        [55],
#        [61],
#        [74],
#        [59],
#        [71],
#        [56],
#        [72],
#        [62],
#        [56],
#        [49],
#        [59],
#        [71],
# ...

# %%
x_test = np.array(x_test).reshape(-1,1)
x_test
# Out:
# array([[64],
#        [65],
#        [60],
#        [56],
#        [74],
#        [62],
#        [21],
#        [53],
#        [69],
#        [70],
#        [51],
#        [51],
#        [65],
#        [54],
#        [63],
#        [74],
#        [63],
#        [66],
#        [57],
#        [60],
#        [63],
#        [60],
#        [70],
#        [67],
#        [51],
#        [64],
#        [62],
#        [57],
#        [61],
#        [62],
#        [69],
#        [81],
#        [63],
#        [54],
#        [66],
#        [70],
#        [61],
#        [57],
#        [56],
#        [76],
#        [63],
#        [58],
#        [77],
#        [68],
#        [60],
#        [58],
#        [71],
#        [54],
#        [56],
#        [62],
#        [60],
#        [49],
#        [62],
#        [59],
#        [69],
#        [69],
#        [64],
#        [56],
#        [64],
#        [56],
#        [48],
#        [55],
#        [70],
#        [56],
#        [68],
#        [62],
# ...

# %%
y_pred_train = m*x_train +c
y_pred_train.flatten()
# Out:
# array([1.56137757, 1.58997602, 1.56137757, 1.51847991, 1.54707835,
#        1.58282641, 1.5149051 , 1.55422796, 1.55780277, 1.57210199,
#        1.54350355, 1.55780277, 1.55780277, 1.5792516 , 1.48988146,
#        1.55065316, 1.53277913, 1.52920432, 1.5149051 , 1.56137757,
#        1.56137757, 1.56137757, 1.55422796, 1.58282641, 1.53635394,
#        1.53992874, 1.58282641, 1.54350355, 1.49703108, 1.54350355,
#        1.57210199, 1.5149051 , 1.60785004, 1.58997602, 1.53277913,
#        1.55065316, 1.52562952, 1.53635394, 1.58282641, 1.47200744,
#        1.61142485, 1.53992874, 1.6435981 , 1.50060588, 1.51847991,
#        1.5756768 , 1.58640121, 1.50418069, 1.55780277, 1.58282641,
#        1.5756768 , 1.60785004, 1.55780277, 1.55422796, 1.52920432,
#        1.55065316, 1.59712563, 1.54350355, 1.58640121, 1.53277913,
#        1.58997602, 1.55422796, 1.53277913, 1.50775549, 1.54350355,
#        1.58640121, 1.58640121, 1.55065316, 1.55780277, 1.59355082,
# ...

# %%
y_pred_train1= reg.predict(x_train)
y_pred_train1
# Out:
# C:\Users\Elaf Fatima\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.56137757, 1.58997602, 1.56137757, 1.51847991, 1.54707835,
#        1.58282641, 1.5149051 , 1.55422796, 1.55780277, 1.57210199,
#        1.54350355, 1.55780277, 1.55780277, 1.5792516 , 1.48988146,
#        1.55065316, 1.53277913, 1.52920432, 1.5149051 , 1.56137757,
#        1.56137757, 1.56137757, 1.55422796, 1.58282641, 1.53635394,
#        1.53992874, 1.58282641, 1.54350355, 1.49703108, 1.54350355,
#        1.57210199, 1.5149051 , 1.60785004, 1.58997602, 1.53277913,
#        1.55065316, 1.52562952, 1.53635394, 1.58282641, 1.47200744,
#        1.61142485, 1.53992874, 1.6435981 , 1.50060588, 1.51847991,
#        1.5756768 , 1.58640121, 1.50418069, 1.55780277, 1.58282641,
#        1.5756768 , 1.60785004, 1.55780277, 1.55422796, 1.52920432,
# ...

# %%
df = pd.read_csv("loan.csv")

# %%
df
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0          2018-01-01   45         39948          617         Employed
# 1          2018-01-02   38         39709          628         Employed
# 2          2018-01-03   47         40724          570         Employed
# 3          2018-01-04   58         69084          545         Employed
# 4          2018-01-05   37        103264          594         Employed
# ...               ...  ...           ...          ...              ...
# 19995      2072-09-29   44         30180          587         Employed
# 19996      2072-09-30   56         49246          567         Employed
# 19997      2072-10-01   44         48958          645         Employed
# 19998      2072-10-02   60         41025          560         Employed
# 19999      2072-10-03   20         53227          574         Employed
#
#       EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Experience'],df['Age'])
plt.xlabel("Experience")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')
